# %% [markdown]
# # Simple gradient descent example

# %%
def quadratic_function(x):
    return x ** 2 - 2 * x + 30

print(0, quadratic_function(0))
# Out:
# 0 30

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate data for plotting
x_vals = np.linspace(-5, 5, 400)
y_vals = quadratic_function(x_vals)

# Plot the function
plt.plot(x_vals, y_vals, label='quadratic_function(x)')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.title('Quadratic Function')
plt.legend()
plt.grid(True)
plt.show()

# %%
import torch
import random

x = torch.tensor([random.uniform(-10, 10)], requires_grad=True)
print("Starting x:", x.item())

for i in range(30):
    y = quadratic_function(x)
    y.backward()
    with torch.no_grad():
        x -= 0.1 * x.grad
    x.grad.zero_()
    print(f"Iteration {i + 1}: x = {x.item()}, f(x) = {y.item()}")
print(f"Optimized x: {x.item()}")
# Out:
# Starting x: 9.280885696411133
# Iteration 1: x = 7.624708652496338, f(x) = 97.57307434082031
# Iteration 2: x = 6.299767017364502, f(x) = 72.88676452636719
# Iteration 3: x = 5.239813804626465, f(x) = 57.08753204345703
# Iteration 4: x = 4.39185094833374, f(x) = 46.97602081298828
# Iteration 5: x = 3.7134807109832764, f(x) = 40.50465393066406
# Iteration 6: x = 3.1707844734191895, f(x) = 36.36297607421875
# Iteration 7: x = 2.7366275787353516, f(x) = 33.712303161621094
# Iteration 8: x = 2.3893020153045654, f(x) = 32.01587677001953
# Iteration 9: x = 2.1114416122436523, f(x) = 30.930160522460938
# Iteration 10: x = 1.889153242111206, f(x) = 30.235301971435547
# Iteration 11: x = 1.711322546005249, f(x) = 29.79059410095215
# Iteration 12: x = 1.5690580606460571, f(x) = 29.505979537963867
# Iteration 13: x = 1.4552464485168457, f(x) = 29.323827743530273
# Iteration 14: x = 1.3641971349716187, f(x) = 29.20724868774414
# Iteration 15: x = 1.2913577556610107, f(x) = 29.132638931274414
# Iteration 16: x = 1.2330862283706665, f(x) = 29.084888458251953
# Iteration 17: x = 1.1864689588546753, f(x) = 29.05432891845703
# Iteration 18: x = 1.1491751670837402, f(x) = 29.034770965576172
# Iteration 19: x = 1.119340181350708, f(x) = 29.022253036499023
# Iteration 20: x = 1.0954720973968506, f(x) = 29.01424217224121
# Iteration 21: x = 1.0763776302337646, f(x) = 29.00911521911621
# Iteration 22: x = 1.0611021518707275, f(x) = 29.00583267211914
# Iteration 23: x = 1.0488817691802979, f(x) = 29.003732681274414
# Iteration 24: x = 1.0391054153442383, f(x) = 29.002389907836914
# Iteration 25: x = 1.0312843322753906, f(x) = 29.001529693603516
# Iteration 26: x = 1.0250275135040283, f(x) = 29.000978469848633
# Iteration 27: x = 1.0200220346450806, f(x) = 29.000625610351562
# Iteration 28: x = 1.0160176753997803, f(x) = 29.00040054321289
# Iteration 29: x = 1.0128141641616821, f(x) = 29.000255584716797
# Iteration 30: x = 1.0102512836456299, f(x) = 29.000164031982422
# Optimized x: 1.0102512836456299
